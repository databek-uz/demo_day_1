# %%
# %sql
create schema if not exists bronze;
create schema if not exists silver; 
create schema if not exists gold;
create volume workspace.default.sales;

# %%
dbutils.fs.cp("/Workspace/Users/balkibumen@gmail.com/demo_day_1/data", "/Volumes/workspace/default/sales", recurse=True)

# %%
# %sql
create or replace table workspace.bronze.metadata (
   id int,
   raw_file string,
   bronze_table string
)

# %%
# %sql
insert into workspace.bronze.metadata (id, raw_file, bronze_table)
values 
(1, "/Volumes/workspace/default/sales/cust_info.csv", "bronze.customers"),
(2, "/Volumes/workspace/default/sales/prd_info.csv", "bronze.products"),
(3, "/Volumes/workspace/default/sales/sales_details.csv", "bronze.sales")

# %%
# %sql
select * from workspace.bronze.metadata
