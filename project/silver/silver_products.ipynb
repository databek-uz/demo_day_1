# %%
import pyspark.sql.functions as F

# %%
bronze_df = spark.table("workspace.bronze.products")

# %%
silver_df = bronze_df.withColumnsRenamed({
    "prd_id": "product_id",
    "prd_key": "product_key",
    "prd_nm": "name",
    "prd_cost": "cost",
    "prd_line": "line",
    "prd_start_dt": "start_date",
    "prd_end_dt": "end_date"
})

# %%
silver_df.write.mode("overwrite").saveAsTable("silver.dim_products")

# TODO: we need implement merge/incermental logic.
