# %%
import pyspark.sql.functions as F

# %%
bronze_df = spark.table("workspace.bronze.sales")
display(bronze_df)

# %%
silver_df = bronze_df.withColumnsRenamed({
    "sls_ord_num": "order_id",
    "sls_prd_key": "product_key",
    "sls_cust_id": "customer_id",
    "sls_order_dt": "order_date",
    "sls_ship_dt": "shipping_date",
    "sls_ship_due": "shipping_due",
    "sls_sales": "sales",
    "sls_quantity": "quantity",
    "sls_price": "price"
})

# %%
silver_df.write.mode("overwrite").saveAsTable("silver.dim_sales")

# TODO: we need implement merge/incermental logic.
